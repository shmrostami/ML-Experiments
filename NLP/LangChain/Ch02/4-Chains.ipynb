# %% [markdown]
# # Chains in LangChain
#
# ## Outline
#
# * LLMChain
# * Sequential Chains
#   * SimpleSequentialChain
#   * SequentialChain
# * Router Chain

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U langchain langchain-openai  openai langchain_community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 15.7 MB/s eta 0:00:00

# %% [markdown]
# Note: LLM's do not always produce the same results. When executing the code in your notebook, you may get slightly different answers that those in the video.

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/LangChain course/Data.csv')

# %%
df
# Out:
#                       Product  \
# 0        Queen Size Sheet Set
# 1      Waterproof Phone Pouch
# 2         Luxury Air Mattress
# 3              Pillows Insert
# 4     Milk Frother Handheld\n
# 5       L'Or Espresso Café \n
# 6  Hervidor de Agua Eléctrico
#
#                                               Review
# 0  I ordered a king size set. My only criticism w...
# 1  I loved the waterproof sac, although the openi...
# 2  This mattress had a small hole in the top of i...
# 3  This is the best throw pillow fillers on Amazo...
# 4   I loved this product. But they only seem to l...
# 5  Je trouve le goût médiocre. La mousse ne tient...
# 6  Está lu bonita calienta muy rápido, es muy fun...

# %% [markdown]
# ## LLMChain

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
from google.colab import userdata
api_key = userdata.get('API_KEY')

# %%
llm = ChatOpenAI(model='meta-llama/llama-3-8b-instruct:free' , temperature=0.9, api_key=api_key, base_url="https://openrouter.ai/api/v1")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
prompt = ChatPromptTemplate.from_template(
    "What is the best name to describe \
    a company that makes {product}?"
)

# %%
chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(

# %%
product = "Queen Size Sheet Set"
chain.run(product)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# 'A Queen-sized task!\n\nHere are some name suggestions for a company that specializes in making Queen-sized sheet sets:\n\n1. Royal Rest Bedding: "Royal" conveys a sense of luxury and royalty, perfect for a queen-sized bedding set.\n2. Queensize Co.: Simple and straightforward, this name immediately conveys what the company offers.\n3. Cloud9 Bedding: This name evokes a sense of comfort and relaxation, which is what people are looking for in a queen-sized sheet set.\n4. Majesty Sheets: This name adds a touch of elegance and sophistication to your product.\n5. The Queen\'s Own Bedding: This name plays on the idea of the Queen\'s own exclusive bedding, making it feel like a high-end, premium product.\n6. Regalia Bedding Co.: "Regalia" means elaborate or luxurious clothes, fitting for a high-quality sheet set.\n7. Heritage Linens: This name suggests a timeless, classic approach to bedding, with a focus on quality materials and craftsmanship.\n8. Serenity Slumber Bedding: This name promises a peaceful, restful sleep, which is what people are seeking in a queen-sized bed.\n9. Luxury Dreams Bedding: This name combines two key selling points: the luxury feel of the bedding and the importance of getting a good night\'s sleep.\n10. Queen Creek Bedding Co.: This name incorporates a natural element (the queen\'s head) with a sense of rustic, wholesome quality, making it approachable and down-to-earth.\n\nWhich one do you think best fits your brand and products?'

# %% [markdown]
# ## SimpleSequentialChain

# %%
from langchain.chains import SimpleSequentialChain

# %%
llm = ChatOpenAI(model='meta-llama/llama-3-8b-instruct:free' , temperature=0.9, api_key=api_key, base_url="https://openrouter.ai/api/v1")
# prompt template 1
first_prompt = ChatPromptTemplate.from_template(
    "What is the best name to describe \
    a company that makes {product}?"
)

# Chain 1
chain_one = LLMChain(llm=llm, prompt=first_prompt)

# %%
# prompt template 2
second_prompt = ChatPromptTemplate.from_template(
    "Write a 20 words description for the following \
    company:{company_name}"
)
# chain 2
chain_two = LLMChain(llm=llm, prompt=second_prompt)

# %%
overall_simple_chain = SimpleSequentialChain(chains=[chain_one, chain_two],
                                             verbose=True
                                            )

# %%
overall_simple_chain.run(product)
# Out:
# > Entering new SimpleSequentialChain chain...
# Here are some name suggestions for a company that makes Queen-size sheet sets:
#
# 1. **Regal Bedding Co.**: "Regal" conveys a sense of luxury and high-quality, fitting for a queen-size sheet set.
# 2. **Queenly Linens**: This name plays off the idea of the queen-size bed being the centerpiece of the bedroom, and "linens" is a broad term that encompasses sheet sets.
# 3. **Royal Sleep Co.**: "Royal" implies a high-end product, and "Sleep Co." emphasizes the company's focus on helping people get a good night's rest.
# 4. **Bedding Majesty**: "Majesty" is a regal word that fits well with the queen-size theme, and "Bedding" is a straightforward description of the company's products.
# 5. **Dreamweave**: This name has a soft, soothing quality to it, and "Dreamweave" implies a focus on creating high-quality, comfortable bedding.
# 6. **Queen's Quilt Co.**: This name incorporates the idea of a queen-size bed and "Quilt Co." suggests a focus on quilting and bedding.
# 7. **Slumber Royale**: "Slumber" is a word associated with sleep and relaxation, and "Royale" adds a touch of luxury to the name.
# 8. **Luxury Linen Works**: This name emphasizes the high-quality materials and craftsmanship that go into the company's sheet sets.
# 9. **The Queen's Bed**: This name is simple and straightforward, emphasizing the company's focus on queen-size bedding.
# 10. **Snooze & Co.**: This name has a playful, approachable tone, and "Snooze" is a word associated with sleep and relaxation.
#
# I hope one of these names sparks your interest and helps you establish your brand identity!
# Here is a 20-word description for Regal Bedding Co.:
#
# "Experience the epitome of luxury with Regal Bedding Co.'s premium Queen-size sheet sets, crafted with attention to detail and a commitment to excellence."
#
# > Finished chain.
# 'Here is a 20-word description for Regal Bedding Co.:\n\n"Experience the epitome of luxury with Regal Bedding Co.\'s premium Queen-size sheet sets, crafted with attention to detail and a commitment to excellence."'

# %% [markdown]
# ## SequentialChain

# %%
from langchain.chains import SequentialChain

# %%
llm = ChatOpenAI(model='meta-llama/llama-3-8b-instruct:free' , temperature=0.9, api_key=api_key, base_url="https://openrouter.ai/api/v1")
# prompt template 1: translate to english
first_prompt = ChatPromptTemplate.from_template(
    "Translate the following review to english:"
    "\n\n{Review}"
)
# chain 1: input= Review and output= English_Review
chain_one = LLMChain(llm=llm, prompt=first_prompt,
                     output_key="English_Review"
                    )

# %%
second_prompt = ChatPromptTemplate.from_template(
    "Can you summarize the following review in 1 sentence:"
    "\n\n{English_Review}"
)
# chain 2: input= English_Review and output= summary
chain_two = LLMChain(llm=llm, prompt=second_prompt,
                     output_key="summary"
                    )

# %%
# prompt template 3: translate to english
third_prompt = ChatPromptTemplate.from_template(
    "What language is the following review:\n\n{Review}"
)
# chain 3: input= Review and output= language
chain_three = LLMChain(llm=llm, prompt=third_prompt,
                       output_key="language"
                      )

# %%
# prompt template 4: follow up message
fourth_prompt = ChatPromptTemplate.from_template(
    "Write a follow up response to the following "
    "summary in the specified language:"
    "\n\nSummary: {summary}\n\nLanguage: {language}"
)
# chain 4: input= summary, language and output= followup_message
chain_four = LLMChain(llm=llm, prompt=fourth_prompt,
                      output_key="followup_message"
                     )

# %%
# overall_chain: input= Review
# and output= English_Review,summary, followup_message
overall_chain = SequentialChain(
    chains=[chain_one, chain_two, chain_three, chain_four],
    input_variables=["Review"],
    output_variables=["English_Review", "summary","followup_message"],
    verbose=True
)

# %%
df
# Out:
#                       Product  \
# 0        Queen Size Sheet Set
# 1      Waterproof Phone Pouch
# 2         Luxury Air Mattress
# 3              Pillows Insert
# 4     Milk Frother Handheld\n
# 5       L'Or Espresso Café \n
# 6  Hervidor de Agua Eléctrico
#
#                                               Review
# 0  I ordered a king size set. My only criticism w...
# 1  I loved the waterproof sac, although the openi...
# 2  This mattress had a small hole in the top of i...
# 3  This is the best throw pillow fillers on Amazo...
# 4   I loved this product. But they only seem to l...
# 5  Je trouve le goût médiocre. La mousse ne tient...
# 6  Está lu bonita calienta muy rápido, es muy fun...

# %%
review = df.Review[5]
overall_chain(review)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# > Entering new SequentialChain chain...
#
# > Finished chain.
# {'Review': "Je trouve le goût médiocre. La mousse ne tient pas, c'est bizarre. J'achète les mêmes dans le commerce et le goût est bien meilleur...\nVieux lot ou contrefaçon !?",
#  'English_Review': "Here is the translation:\n\nI find the taste mediocre. The mousse doesn't hold up, it's weird. I buy the same ones at the store and the taste is much better...\n\nFake or old stock!",
#  'summary': "The reviewer finds the taste of the mousse to be mediocre, complaining that it doesn't hold up and tastes better when bought fresh from a store.",
#  'followup_message': "Réponse :\n\nJe suis désolé d'entendre que vous n'êtes pas satisfait de la saveur de la mousse que vous avez achetée. Je comprends que la qualité peut varier en fonction de la date de consommation et de la méthode de stockage. Cependant, je voudrais vous signaler que nous prenons très au sérieux les commentaires de nos clients et que nous allons prendre des mesures pour améliorer la conservation de nos produits.\n\nJe vous invite également à essayer notre mousse fraîcheement sortie de nos usines, comme vous l'avez déjà fait. Nous sommes convaincus que vous apprécierez la différence de qualité et de saveur. Si vous avez des questions ou des préoccupations, n'hésitez pas à nous contacter.\n\nCordialement,\n[Votre nom]\n\nTranslation:\n\nResponse:\n\nI'm sorry to hear that you're not satisfied with the taste of the mousse you bought. I understand that quality can vary depending on the consumption date and storage method. However, I would like to inform you that we take our customers' comments very seriously and will take measures to improve the conservation of our products.\n\nI also invite you to try our fresh mousse straight from our factories, as you have already done. We are convinced that you will appreciate the difference in quality and taste. If you have any questions or concerns, don't hesitate to contact us.\n\nBest regards,\n[Your name]"}

# %% [markdown]
# ## Router Chain

# %%
physics_template = """You are a very smart physics professor. \
You are great at answering questions about physics in a concise\
and easy to understand manner. \
When you don't know the answer to a question you admit\
that you don't know.

Here is a question:
{input}"""


math_template = """You are a very good mathematician. \
You are great at answering math questions. \
You are so good because you are able to break down \
hard problems into their component parts,
answer the component parts, and then put them together\
to answer the broader question.

Here is a question:
{input}"""

history_template = """You are a very good historian. \
You have an excellent knowledge of and understanding of people,\
events and contexts from a range of historical periods. \
You have the ability to think, reflect, debate, discuss and \
evaluate the past. You have a respect for historical evidence\
and the ability to make use of it to support your explanations \
and judgements.

Here is a question:
{input}"""


computerscience_template = """ You are a successful computer scientist.\
You have a passion for creativity, collaboration,\
forward-thinking, confidence, strong problem-solving capabilities,\
understanding of theories and algorithms, and excellent communication \
skills. You are great at answering coding questions. \
You are so good because you know how to solve a problem by \
describing the solution in imperative steps \
that a machine can easily interpret and you know how to \
choose a solution that has a good balance between \
time complexity and space complexity.

Here is a question:
{input}"""

# %%
prompt_infos = [
    {
        "name": "physics",
        "description": "Good for answering questions about physics",
        "prompt_template": physics_template
    },
    {
        "name": "math",
        "description": "Good for answering math questions",
        "prompt_template": math_template
    },
    {
        "name": "History",
        "description": "Good for answering history questions",
        "prompt_template": history_template
    },
    {
        "name": "computer science",
        "description": "Good for answering computer science questions",
        "prompt_template": computerscience_template
    }
]

# %%
from langchain.chains.router import MultiPromptChain
from langchain.chains.router.llm_router import LLMRouterChain,RouterOutputParser
from langchain.prompts import PromptTemplate

# %%
llm = ChatOpenAI(model='meta-llama/llama-3-8b-instruct:free' , temperature=0, api_key=api_key, base_url="https://openrouter.ai/api/v1")

# %%
destination_chains = {}
for p_info in prompt_infos:
    name = p_info["name"]
    prompt_template = p_info["prompt_template"]
    prompt = ChatPromptTemplate.from_template(template=prompt_template)
    chain = LLMChain(llm=llm, prompt=prompt)
    destination_chains[name] = chain

destinations = [f"{p['name']}: {p['description']}" for p in prompt_infos]
destinations_str = "\n".join(destinations)

# %%
default_prompt = ChatPromptTemplate.from_template("{input}")
default_chain = LLMChain(llm=llm, prompt=default_prompt)

# %%
MULTI_PROMPT_ROUTER_TEMPLATE = """Given a raw text input to a \
language model select the model prompt best suited for the input. \
You will be given the names of the available prompts and a \
description of what the prompt is best suited for. \
You may also revise the original input if you think that revising\
it will ultimately lead to a better response from the language model.

<< FORMATTING >>
Return a markdown code snippet with a JSON object formatted to look like:
```json
{{{{
    "destination": string \ name of the prompt to use or "DEFAULT"
    "next_inputs": string \ a potentially modified version of the original input
}}}}
```

REMEMBER: "destination" MUST be one of the candidate prompt \
names specified below OR it can be "DEFAULT" if the input is not\
well suited for any of the candidate prompts.
REMEMBER: "next_inputs" can just be the original input \
if you don't think any modifications are needed.

<< CANDIDATE PROMPTS >>
{destinations}

<< INPUT >>
{{input}}

<< OUTPUT (remember to include the ```json)>>"""

# %%
router_template = MULTI_PROMPT_ROUTER_TEMPLATE.format(
    destinations=destinations_str
)
router_prompt = PromptTemplate(
    template=router_template,
    input_variables=["input"],
    output_parser=RouterOutputParser(),
)

router_chain = LLMRouterChain.from_llm(llm, router_prompt)

# %%
chain = MultiPromptChain(router_chain=router_chain,
                         destination_chains=destination_chains,
                         default_chain=default_chain, verbose=True
                        )

# %%
chain.run("What is black body radiation?")
# Out:
# > Entering new MultiPromptChain chain...
# physics: {'input': 'What is black body radiation in the context of thermodynamics?'}
# > Finished chain.
# "Black body radiation is a fundamental concept in thermodynamics, and it's a fascinating topic.\n\nIn simple terms, black body radiation refers to the thermal radiation emitted by an idealized object, known as a blackbody, when it's heated to a high temperature. The key characteristic of a blackbody is that it absorbs all the radiation that falls on it, without reflecting or transmitting any of it.\n\nWhen a blackbody is heated, it begins to emit radiation across a wide range of wavelengths, from infrared to ultraviolet and even X-rays. This radiation is known as black body radiation. The important thing to note is that the radiation is emitted in all directions, and it's not directional like light from a laser or a flashlight.\n\nThe distribution of this radiation is described by Planck's law, which was developed by Max Planck in the early 20th century. Planck's law states that the energy density of the radiation is directly proportional to the fourth power of the temperature of the blackbody. This means that as the temperature of the blackbody increases, the energy density of the radiation it emits also increases rapidly.\n\nBlack body radiation has many important applications in physics and engineering, including the design of thermal imaging systems, radiation detectors, and even the development of new materials with specific thermal properties.\n\nI hope that helps! Do you have any follow-up questions about black body radiation?"

# %%
chain.run("what is 2 + 2")
# Out:
# > Entering new MultiPromptChain chain...
# math: {'input': 'what is 2 + 2'}
# > Finished chain.
# 'A classic!\n\nTo answer this question, I\'ll break it down into its component parts:\n\n1. What is the definition of addition?\n\nAddition is a binary operation that combines two numbers to produce a sum. In this case, we\'re adding 2 and 2.\n\n2. What are the values of the numbers being added?\n\nThe numbers being added are 2 and 2. We can represent this as:\n\n2 + 2 =?\n\n3. What is the result of combining these numbers?\n\nTo combine these numbers, we can use the definition of addition: the sum of two numbers is the result of counting how many times the first number fits into the second number, and then adding 1.\n\nIn this case, we can count how many times 2 fits into 2:\n\n2 fits into 2 exactly once.\n\nSo, the result of combining 2 and 2 is:\n\n2 + 2 = 4\n\nTherefore, the answer to the question "what is 2 + 2" is 4!'

# %%
chain.run("Why does every cell in our body contain DNA?")
# Out:
# > Entering new MultiPromptChain chain...
# physics: {'input': 'Why does every cell in our body contain DNA? (biology)'}
# > Finished chain.
# "What a great question! While I'm a physics professor, I'm happy to venture into the realm of biology to provide an answer.\n\nThe reason every cell in our body contains DNA is because DNA (deoxyribonucleic acid) is the molecule that contains the genetic instructions used in the development and function of all living organisms. In other words, DNA is the blueprint or instruction manual for our cells.\n\nThink of DNA as a set of instructions that tells our cells what to do, how to grow, and how to function. It's like a recipe book for our cells, and every cell needs a copy of that recipe book to follow.\n\nIn every cell, DNA is wrapped around proteins called histones to form structures called chromosomes. These chromosomes contain the genetic information that determines the characteristics of an organism, such as eye color, hair color, height, and other traits.\n\nHaving a copy of DNA in every cell allows our cells to:\n\n1. Reproduce themselves: Cells can use their DNA to create new copies of themselves, ensuring the continuation of life.\n2. Respond to environmental changes: Cells can use their DNA to adapt to changes in their environment, such as changes in temperature, light, or nutrient availability.\n3. Maintain cellular identity: Cells can use their DNA to maintain their unique characteristics and functions, such as muscle cells being able to contract or nerve cells being able to transmit signals.\n\nIn summary, every cell in our body contains DNA because it's essential for the development, function, and reproduction of cells. Without DNA, our cells wouldn't know what to do or how to function, and life as we know it wouldn't be possible!"
